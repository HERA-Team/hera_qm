# %%
# %matplotlib notebook
from hera_qm import utils
from hera_qm.xrfi import detrend_medfilt
import numpy as np
import matplotlib.pyplot as plt

# %%
nt = 60
nf = 1024
nbl = 100
rfi_amp = 30

# %%
np.random.seed(100)
indata = np.random.normal(size=(nt, nf, nbl)) + 1j * np.random.normal(size=(nt, nf, nbl))
indata[45, 300, :] = np.random.normal(scale=rfi_amp, size=nbl) + 1j * np.random.normal(scale=rfi_amp, size=nbl)
for i in range(nbl):
    indata[:, :, i] = detrend_medfilt(np.abs(indata[:, :, i]))

# %%
indata.imag.min()
# Out:
# 0.0

# %%
indata = indata.astype(np.float)
out1 = utils.quadmean(indata, axis=2)
out2 = utils.squadmean(indata, axis=2)
out1 = detrend_medfilt(out1)
out2 = detrend_medfilt(out2)
# Out:
# /Users/abeardsley/anaconda/envs/HERA/lib/python2.7/site-packages/ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.

# %%
plt.figure()
ax1 = plt.subplot(211)
plt.imshow(out1, aspect='auto')
plt.colorbar()
plt.subplot(212, sharex=ax1, sharey=ax1)
plt.imshow(out2, aspect='auto')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(out1.flatten(), alpha=0.5, label='quadmean')
plt.hist(out2.flatten(), alpha=0.5, label='squadmean')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([6.2900e+03, 2.4371e+04, 2.4796e+04, 5.9820e+03, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-9.36468259e-01, -4.67021060e-01,  2.42613891e-03,  4.71873338e-01,
#          9.41320537e-01,  1.41076774e+00,  1.88021493e+00,  2.34966213e+00,
#          2.81910933e+00,  3.28855653e+00,  3.75800373e+00]),
#  <a list of 10 Patch objects>)

# %%
a = np.random.normal(size=(1000, 1000))
print(np.std(np.mean(a, axis=0)))
print(np.std(np.mean(np.abs(a), axis=0)))
# Out:
# 0.032090362533606226
# 0.01835273765362377
